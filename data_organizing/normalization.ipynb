# %%
import numpy as np
import openpyxl as xl
import os
import nibabel as nb
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.transform import resize

# image = np.array(nib.load(path).get_fdata())

base_dir = '/home/NAS_mount/thum/_raw_data/BraTS2021_Training_Data'

patient_list = os.listdir(base_dir)



for idx, sub_name in enumerate(patient_list): # sub_name is subject name
    sub_path = os.path.join(base_dir, sub_name)

    contrast_names = os.listdir(sub_path)

    param = {}


    for cont_name in contrast_names:
        cont_path = os.path.join(sub_path, cont_name) 

        cont_type = cont_name.split('.')[0].split('_')[-1] # type of contrast
        # print(cont_type)

        cont = np.array(nb.load(cont_path).get_fdata()) # npy array

        cont_tr = cont.transpose(2, 0, 1)
        # print(cont_tr.shape) # 155, 240, 240

        # cont_tr = cont_tr/cont_tr.max()

        # if cont_type == 'flair':
        
        param['mean'] = cont_tr.mean()
        param['max'] = cont_tr.max()
        param['min'] = cont_tr.min()
        param['std'] = cont_tr.std()

        # print('mean', cont_tr.mean())
        # print('max', cont_tr.max())
        # print('min', cont_tr.min())
        # print('std', cont_tr.std())

        cont_z = (cont_tr - cont_tr.mean())/cont_tr.std()

        if cont_type == 'seg':
            cont_tr = (cont_tr > 0).astype('uint8')
            print(cont_tr.max())
            print(cont_tr.min())

        # for i in range(155):
        #     if i%10 == 0:
                # original = cont_tr[i]
                # # print('original sum ', original.sum())
                # # print('original mean ',original.mean())
                # # print('origianal.max() - origianl.min()', original.max() - original.min() )

                # min_max = (cont_tr[i] - param['min'])/(param['max'] - param['min'])
                # # print('min max sum ', min_max.sum())
                # # print('min max mean ',min_max.mean())
                # # print('min max.max() - min max.min()', min_max.max() - min_max.min() )

                # z_score = (cont_tr[i] - param['mean']) / param['std']
                # print('z_score sum ', z_score.sum())
                # print('z_score mean ',z_score.mean())
                # print('z_score max ',z_score.max())
                # print('z_score diff', z_score.max() - z_score.min() )

                # z_score_mm = (cont_z[i] - cont_z.min())/(cont_z.max() - cont_z.min())
                # print('z_score_mm sum ', z_score_mm.sum())
                # print('z_score_mm mean ',z_score_mm.mean())
                # print('z_score_mm max ',z_score_mm.max())
                # print('z_score_mm diff', z_score_mm.max() - z_score_mm.min() )

                # plt.rcParams["figure.figsize"] = (15,5)
                # plt.subplot(1, 3, 1)
                # plt.imshow(original)
                # plt.subplot(1, 3, 2)
                # plt.title(cont_type + str(i))
                # plt.imshow(z_score)
                # plt.subplot(1, 3, 3)
                # plt.imshow(z_score_mm)
                # plt.show()


                # plt.title('difference between origianl, min_max',)
                # plt.imshow(original - min_max)
                # plt.show()
                # plt.title('difference between origianl, z_score',)
                # plt.imshow(original - z_score)
                # plt.show()


    if idx == 1: break
# Out:
# 1
# 0
# 1
# 0
